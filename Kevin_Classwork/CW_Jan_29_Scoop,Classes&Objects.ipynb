# %%
class a_sample_class:
    def __init__(self):
        self.var = 0

    def print_vars(self):
        print(self.var)

obj = a_sample_class()

obj.print_vars()
# Out:
# 0

# %% [markdown]
# # Constructor
# __init__ (__ is dunder)
# SELF is a default variable that contains the memory address of the current code you're working with.

# %%
class a_sample_class:
    def __init__(self, one, two):
        self.first = one

    def print_vars(self):
        print(self.first)

obj = a_sample_class(2,5)

obj.print_vars()
# Out:
# 2

# %%
class a_sample_class:
    def __init__(self, one, two):
        self.first = one

    def print_vars(self):
        print(self.first)

obj = a_sample_class(1,5)

obj.print_vars()
# Out:
# 1

# %%
class a_sample_class:
    class_attr = 5
    
    def __init__(self, one, two):
        self.first = one
        self.second = two

obj = a_sample_class(17,42)
print(obj.first)
print(obj.class_attr)
print(a_sample_class.first)
print(a_sample_class.class_attr)
# Out:
# 17
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       9 print(obj.first)
#      10 print(obj.class_attr)
# ---> 11 print(a_sample_class.first)
#      12 print(a_sample_class.class_attr)
#
# AttributeError: type object 'a_sample_class' has no attribute 'first'

# %%
class a_sample_class:
    class_attr = 5
    
    def __init__(self, one, two):
        self.first = one
        self.second = two

obj = a_sample_class(17,42)
print(obj.first)
print(obj.class_attr)
#print(a_sample_class.first)
print(a_sample_class.class_attr)
# Out:
# 17
# 5
# 5

# %% [markdown]
# # Instance Attributes & Class Attributes
# 2 scopes for attributes
#
# instance attribute = variable that belongs to a specific instance or instantiation. Defined inside the constructor (init). Can access from the scope of an object (local)
#
# Class attribute = type of variable that belongs to the class itself. Defined outside the constructor. Similar to static attributes in Java.

# %%
help(obj)
# Out:
# Help on a_sample_class in module __main__ object:
#
# class a_sample_class(builtins.object)
#  |  a_sample_class(one, two)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, one, two)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  class_attr = 5

# %%
# directory of names
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a_sample_class',
#  'a_sample_clsss',
#  'exit',
#  'get_ipython',
#  'obj',
#  'open',
#  'quit']

# %%
# returns the current module namespace
# namespace = mapping between objects and current names
# these are defined names & they include references points
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class a_sample_clsss:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(2,5)\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(1,5)\n\nobj.print_vars()',
#   'class a_sample_class:\n    class_attr = \n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\n#print(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'help(obj)',
#   '#\ndir()',
#   '# directory of names\ndir()',
#   'globals()',
#   '# returns the current module namespace\n# namespace = mapping between objects and current names\nglobals()'],
#  '_oh': {9: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__session__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'a_sample_class',
#    'a_sample_clsss',
#    'exit',
#    'get_ipython',
#    'obj',
#    'open',
#    'quit'],
#   10: ['In',
#    'Out',
#    '_',
#    '_9',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__session__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'a_sample_class',
#    'a_sample_clsss',
#    'exit',
#    'get_ipython',
#    'obj',
#    'open',
#    'quit'],
#   11: {...}},
#  '_dh': [PosixPath('/Users/kevinpatel/Documents/CSCI_1070_patel/Kevin_csci_1070/Kevin_Classwork')],
#  'In': ['',
#   'class a_sample_clsss:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(2,5)\n\nobj.print_vars()',
#   'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(1,5)\n\nobj.print_vars()',
#   'class a_sample_class:\n    class_attr = \n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\n#print(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#   'help(obj)',
#   '#\ndir()',
#   '# directory of names\ndir()',
#   'globals()',
#   '# returns the current module namespace\n# namespace = mapping between objects and current names\nglobals()'],
#  'Out': {9: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__session__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'a_sample_class',
#    'a_sample_clsss',
#    'exit',
#    'get_ipython',
#    'obj',
#    'open',
#    'quit'],
#   10: ['In',
#    'Out',
#    '_',
#    '_9',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__session__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i10',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_i6',
#    '_i7',
#    '_i8',
#    '_i9',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'a_sample_class',
#    'a_sample_clsss',
#    'exit',
#    'get_ipython',
#    'obj',
#    'open',
#    'quit'],
#   11: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10cb145f0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10cb14e90>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10cb14e90>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': ['In',
#   'Out',
#   '_',
#   '_9',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__session__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'a_sample_class',
#   'a_sample_clsss',
#   'exit',
#   'get_ipython',
#   'obj',
#   'open',
#   'quit'],
#  '___': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__session__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'a_sample_class',
#   'a_sample_clsss',
#   'exit',
#   'get_ipython',
#   'obj',
#   'open',
#   'quit'],
#  '__session__': '/Users/kevinpatel/Documents/CSCI_1070_patel/Kevin_csci_1070/Kevin_Classwork/Untitled.ipynb',
#  '_i': 'globals()',
#  '_ii': '# directory of names\ndir()',
#  '_iii': '#\ndir()',
#  '_i1': 'class a_sample_clsss:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#  'a_sample_clsss': __main__.a_sample_clsss,
#  '_i2': 'class a_sample_class:\n    def __init__(self):\n        self.var = 0\n\n    def print_vars(self):\n        print(self.var)\n\nobj = a_sample_class()\n\nobj.print_vars()',
#  'a_sample_class': __main__.a_sample_class,
#  'obj': <__main__.a_sample_class at 0x10cc6b710>,
#  '_i3': 'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(2,5)\n\nobj.print_vars()',
#  '_i4': 'class a_sample_class:\n    def __init__(self, one, two):\n        self.first = one\n\n    def print_vars(self):\n        print(self.first)\n\nobj = a_sample_class(1,5)\n\nobj.print_vars()',
#  '_i5': 'class a_sample_class:\n    class_attr = \n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#  '_i6': 'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\nprint(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#  '_i7': 'class a_sample_class:\n    class_attr = 5\n    \n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n\nobj = a_sample_class(17,42)\nprint(obj.first)\nprint(obj.class_attr)\n#print(a_sample_class.first)\nprint(a_sample_class.class_attr)',
#  '_i8': 'help(obj)',
#  '_i9': '#\ndir()',
#  '_9': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__session__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'a_sample_class',
#   'a_sample_clsss',
#   'exit',
#   'get_ipython',
#   'obj',
#   'open',
#   'quit'],
#  '_i10': '# directory of names\ndir()',
#  '_10': ['In',
#   'Out',
#   '_',
#   '_9',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__session__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i10',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'a_sample_class',
#   'a_sample_clsss',
#   'exit',
#   'get_ipython',
#   'obj',
#   'open',
#   'quit'],
#  '_i11': 'globals()',
#  '_11': {...},
#  '_i12': '# returns the current module namespace\n# namespace = mapping between objects and current names\nglobals()'}

# %%
# class, instances, static methods
class candy:
    def __init__(self,
                 _brand,
                 _is_caramel=False,
                 _has_nuts=False,
                 _calories=300,
                 _type='chocolate',
                 _size='king'):
        self.type= _type
        self.brand= _brand
        self.is_caramel= _is_caramel
        self.calories= _calories
        self.has_nuts= _has_nuts
        self.size= _size


# instance method can access and modify both the class and instance state, printing is accessing the state
    def display(self):
        print(f'My Favorite candy is {self.brand} {self.type}')

    @classmethod
    def snickers(clas

# %%
fav_candy = candy(_brand='M&M')

# %%
fav_candy.display()
# Out:
# My Favorite candy is M&M chocolate

# %%
 @classmethod
def snickers(cls):
        returncls('snickers',_is_caramel=True,_has_nuts=True)

#static method
    @staticmethod
def calories(size,n):
    if size == 'large':
        calories = 500
    elif size == 'regular':
        calories = 350
    elif size == 'funsized':
        calories = 100
